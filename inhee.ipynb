# %%
# pip install openpyxl

# %%
# 데이터 처리
import pandas as pd
import numpy as np

# 시각화
import matplotlib.pyplot as plt
import seaborn as sns

# 모델 및 평가
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc
from sklearn.inspection import permutation_importance

# 부스터 모델
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %% [markdown]
# 롤(게임) 유저들의 게임 데이터를 기반으로 승,패를 예측하는 모델 개발
#
# 1. 데이터 불러오기
# 2. 데이터 전처리
#    - NULL 값 처리
#    - 더미변수
# 3. 머신러닝 : 로지스틱회귀분석, 랜덤포레스트, decisiontree, xgboost, lightgbm
# 4. 성능평가 : AUC,ROC

# %% [markdown]
# # 데이터 불러오기

# %%
df = pd.read_excel('league_data.xlsx')

# %%
# 데이터 확인
df.head(5)
# Out:
#       game_id      game_start_utc  game_duration game_mode     game_type  \
# 0  3727443167 2025-01-15 14:56:00           1714   CLASSIC  MATCHED_GAME
# 1  3726377460 2025-01-13 10:50:00           1300   CLASSIC  MATCHED_GAME
# 2  3729643655 2025-01-19 18:15:00           2019   CLASSIC  MATCHED_GAME
# 3  3729915593 2025-01-20 01:27:00           1625   CLASSIC  MATCHED_GAME
# 4  3729901665 2025-01-20 00:40:00           1542   CLASSIC  MATCHED_GAME
#
#     game_version  map_id platform_id  queue_id  participant_id  ...  \
# 0  15.1.649.4112      11        EUN1       420               5  ...
# 1  15.1.648.3927      11        EUN1       420               5  ...
# 2  15.1.649.4112      11        EUN1       420               2  ...
# 3  15.1.649.4112      11        EUN1       420               8  ...
# 4  15.1.649.4112      11        EUN1       420              10  ...
#
#   final_magicPen final_magicPenPercent final_magicResist  final_movementSpeed  \
# 0              0                     0                48                  385
# 1              0                     0                38                  390
# 2              0                     0               121                  431
# 3             12                     0                47                  380
# 4              0                     0                40                  534
#
#    final_omnivamp final_physicalVamp  final_power  final_powerMax  \
# 0               0                  0          799            1134
# 1               0                  0          970             970
# 2               0                  0        10000           10000
# 3               0                  0         1122            1596
# 4               0                  0         1025            1025
#
#   final_powerRegen final_spellVamp
# 0              147               0
# 1              105               0
# 2                0               0
# 3               37               0
# 4              109               0
#
# [5 rows x 94 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40410 entries, 0 to 40409
# Data columns (total 94 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   game_id                                40410 non-null  int64
#  1   game_start_utc                         40410 non-null  datetime64[ns]
#  2   game_duration                          40410 non-null  int64
#  3   game_mode                              40410 non-null  object
#  4   game_type                              40410 non-null  object
#  5   game_version                           40410 non-null  object
#  6   map_id                                 40410 non-null  int64
#  7   platform_id                            40410 non-null  object
#  8   queue_id                               40410 non-null  int64
#  9   participant_id                         40410 non-null  int64
#  10  puuid                                  40410 non-null  object
#  11  summoner_name                          38102 non-null  object
#  12  summoner_id                            40410 non-null  object
#  13  summoner_level                         40410 non-null  int64
#  14  champion_id                            40410 non-null  int64
#  15  champion_name                          40410 non-null  object
#  16  team_id                                40410 non-null  int64
#  17  win                                    40410 non-null  bool
#  18  individual_position                    40410 non-null  object
#  19  team_position                          30662 non-null  object
#  20  lane                                   40410 non-null  object
#  21  role                                   40410 non-null  object
#  22  kills                                  40410 non-null  int64
#  23  deaths                                 40410 non-null  int64
#  24  assists                                40410 non-null  int64
#  25  baron_kills                            40410 non-null  int64
#  26  dragon_kills                           40410 non-null  int64
#  27  gold_earned                            40410 non-null  int64
#  28  gold_spent                             40410 non-null  int64
#  29  total_damage_dealt                     40410 non-null  int64
#  30  total_damage_dealt_to_champions        40410 non-null  int64
#  31  physical_damage_dealt_to_champions     40410 non-null  int64
#  32  magic_damage_dealt_to_champions        40410 non-null  int64
#  33  true_damage_dealt_to_champions         40410 non-null  int64
#  34  damage_dealt_to_objectives             40410 non-null  int64
#  35  damage_dealt_to_turrets                40410 non-null  int64
#  36  total_damage_taken                     40410 non-null  int64
#  37  physical_damage_taken                  40410 non-null  int64
#  38  magic_damage_taken                     40410 non-null  int64
#  39  true_damage_taken                      40410 non-null  int64
#  40  time_ccing_others                      40410 non-null  int64
#  41  vision_score                           40410 non-null  int64
#  42  wards_placed                           40410 non-null  int64
#  43  wards_killed                           40410 non-null  int64
#  44  vision_wards_bought_in_game            40410 non-null  int64
#  45  item0                                  40410 non-null  int64
#  46  item1                                  40410 non-null  int64
#  47  item2                                  40410 non-null  int64
#  48  item3                                  40410 non-null  int64
#  49  item4                                  40410 non-null  int64
#  50  item5                                  40410 non-null  int64
#  51  item6                                  40410 non-null  int64
#  52  solo_tier                              27866 non-null  object
#  53  solo_rank                              27866 non-null  object
#  54  solo_lp                                27866 non-null  float64
#  55  solo_wins                              27866 non-null  float64
#  56  solo_losses                            27866 non-null  float64
#  57  flex_tier                              10363 non-null  object
#  58  flex_rank                              10363 non-null  object
#  59  flex_lp                                10363 non-null  float64
#  60  flex_wins                              10363 non-null  float64
#  61  flex_losses                            10363 non-null  float64
#  62  champion_mastery_level                 40380 non-null  float64
#  63  champion_mastery_points                40380 non-null  float64
#  64  champion_mastery_lastPlayTime          40380 non-null  float64
#  65  champion_mastery_lastPlayTime_utc      40380 non-null  datetime64[ns]
#  66  champion_mastery_pointsSinceLastLevel  40380 non-null  float64
#  67  champion_mastery_pointsUntilNextLevel  40380 non-null  float64
#  68  champion_mastery_tokensEarned          40380 non-null  float64
#  69  final_abilityHaste                     40410 non-null  int64
#  70  final_abilityPower                     40410 non-null  int64
#  71  final_armor                            40410 non-null  int64
#  72  final_armorPen                         40410 non-null  int64
#  73  final_armorPenPercent                  40410 non-null  int64
#  74  final_attackDamage                     40410 non-null  int64
#  75  final_attackSpeed                      40410 non-null  int64
#  76  final_bonusArmorPenPercent             40410 non-null  int64
#  77  final_bonusMagicPenPercent             40410 non-null  int64
#  78  final_ccReduction                      40410 non-null  int64
#  79  final_cooldownReduction                40410 non-null  int64
#  80  final_health                           40410 non-null  int64
#  81  final_healthMax                        40410 non-null  int64
#  82  final_healthRegen                      40410 non-null  int64
#  83  final_lifesteal                        40410 non-null  int64
#  84  final_magicPen                         40410 non-null  int64
#  85  final_magicPenPercent                  40410 non-null  int64
#  86  final_magicResist                      40410 non-null  int64
#  87  final_movementSpeed                    40410 non-null  int64
#  88  final_omnivamp                         40410 non-null  int64
#  89  final_physicalVamp                     40410 non-null  int64
#  90  final_power                            40410 non-null  int64
#  91  final_powerMax                         40410 non-null  int64
#  92  final_powerRegen                       40410 non-null  int64
#  93  final_spellVamp                        40410 non-null  int64
# dtypes: bool(1), datetime64[ns](2), float64(12), int64(63), object(16)
# memory usage: 28.7+ MB

# %%
df['game_mode'].value_counts()
# Out:
# game_mode
# CLASSIC      29400
# ARAM          9730
# SWIFTPLAY     1280
# Name: count, dtype: int64

# %%
# game_mode가 'CLASSIC'인 게임만 필터링 (소환사의 협곡 게임만 분석)
df = df[df['game_mode'] == 'CLASSIC']

# %% [markdown]
# # 불필요한 컬럼 제거

# %%
# 데이터의 행,열의 개수
df.shape
# Out:
# (29400, 94)

# %%
df.columns
# Out:
# Index(['game_id', 'game_start_utc', 'game_duration', 'game_mode', 'game_type',
#        'game_version', 'map_id', 'platform_id', 'queue_id', 'participant_id',
#        'puuid', 'summoner_name', 'summoner_id', 'summoner_level',
#        'champion_id', 'champion_name', 'team_id', 'win', 'individual_position',
#        'team_position', 'lane', 'role', 'kills', 'deaths', 'assists',
#        'baron_kills', 'dragon_kills', 'gold_earned', 'gold_spent',
#        'total_damage_dealt', 'total_damage_dealt_to_champions',
#        'physical_damage_dealt_to_champions', 'magic_damage_dealt_to_champions',
#        'true_damage_dealt_to_champions', 'damage_dealt_to_objectives',
#        'damage_dealt_to_turrets', 'total_damage_taken',
#        'physical_damage_taken', 'magic_damage_taken', 'true_damage_taken',
#        'time_ccing_others', 'vision_score', 'wards_placed', 'wards_killed',
#        'vision_wards_bought_in_game', 'item0', 'item1', 'item2', 'item3',
#        'item4', 'item5', 'item6', 'solo_tier', 'solo_rank', 'solo_lp',
#        'solo_wins', 'solo_losses', 'flex_tier', 'flex_rank', 'flex_lp',
#        'flex_wins', 'flex_losses', 'champion_mastery_level',
#        'champion_mastery_points', 'champion_mastery_lastPlayTime',
#        'champion_mastery_lastPlayTime_utc',
#        'champion_mastery_pointsSinceLastLevel',
#        'champion_mastery_pointsUntilNextLevel',
#        'champion_mastery_tokensEarned', 'final_abilityHaste',
#        'final_abilityPower', 'final_armor', 'final_armorPen',
#        'final_armorPenPercent', 'final_attackDamage', 'final_attackSpeed',
#        'final_bonusArmorPenPercent', 'final_bonusMagicPenPercent',
#        'final_ccReduction', 'final_cooldownReduction', 'final_health',
#        'final_healthMax', 'final_healthRegen', 'final_lifesteal',
#        'final_magicPen', 'final_magicPenPercent', 'final_magicResist',
#        'final_movementSpeed', 'final_omnivamp', 'final_physicalVamp',
#        'final_power', 'final_powerMax', 'final_powerRegen', 'final_spellVamp'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#           game_id      game_start_utc  game_duration game_mode     game_type  \
# 27377  3722827419 2025-01-06 20:25:00           1819   CLASSIC  MATCHED_GAME
# 9041   3729192364 2025-01-18 21:33:00           1740   CLASSIC  MATCHED_GAME
# 2621   3727963925 2025-01-16 16:57:00           1352   CLASSIC  MATCHED_GAME
# 27801  3720571237 2025-01-02 21:36:00           1476   CLASSIC  MATCHED_GAME
# 11885  3728059126 2025-01-16 19:30:00           1603   CLASSIC  MATCHED_GAME
#
#          game_version  map_id platform_id  queue_id  participant_id  ...  \
# 27377  14.24.644.2327      11        EUN1       400               3  ...
# 9041    15.1.649.4112      11        EUN1       420               9  ...
# 2621    15.1.649.4112      11        EUN1       420               4  ...
# 27801  14.24.644.2327      11        EUN1       420               1  ...
# 11885   15.1.649.4112      11        EUN1       420               8  ...
#
#       final_magicPen final_magicPenPercent final_magicResist  \
# 27377             12                     0                65
# 9041               0                     0                56
# 2621               0                     0                44
# 27801              0                     0                50
# 11885             44                     0                64
#
#        final_movementSpeed  final_omnivamp final_physicalVamp  final_power  \
# 27377                  400               0                  0         1008
# 9041                   384               0                  0         1838
# 2621                   521               0                  0          738
# 27801                  409               0                  0          535
# 11885                  423               0                  0          200
#
#        final_powerMax final_powerRegen final_spellVamp
# 27377            1246               35               0
# 9041             1838              270               0
# 2621              738               33               0
# 27801             656               24               0
# 11885             200              100               0
#
# [5 rows x 94 columns]

# %%
# 불필요한 기본 정보 컬럼 제거
df_drop = df.drop([
    'game_start_utc', 'game_type', 'game_version', 'map_id', 'platform_id','summoner_name',
    'participant_id', 'puuid', 'summoner_name', 'summoner_id', 'summoner_level',
    'champion_id', 'champion_name', 'individual_position', 'lane', 'role',
    'item0', 'item1', 'item2', 'item3', 'item4', 'item5', 'item6',
    'champion_mastery_lastPlayTime', 'champion_mastery_lastPlayTime_utc',
    'champion_mastery_pointsSinceLastLevel', 'champion_mastery_pointsUntilNextLevel',
    'champion_mastery_tokensEarned', 'final_abilityHaste',
    'flex_tier', 'flex_rank', 'flex_lp', 'flex_wins', 'flex_losses','game_mode', 'solo_lp'
], axis='columns')

# %% [markdown]
# # 결측치 처리

# %% [markdown]
# - team_position 결측치 행 삭제
# - solo에 대한 정보가 결측치가 있는 이유 : 언랭 티어 존재.
#     - solo_tier 결측치 -> Unranked로 대체
#     - solo_rank 결측치 -> 1로 대체 (추후, solo_tier와 합칠 예정)
#     - solo_wins, solo_losses 결측치 -> 0으로 대체
# - champion_mastery_level, champion_mastery_points -> 평균값 대체

# %%
# 결측치 확인
df_drop.isnull().sum()[df.isnull().sum() > 0]
# Out:
# team_position                16
# solo_tier                  4621
# solo_rank                  4621
# solo_wins                  4621
# solo_losses                4621
# champion_mastery_level        8
# champion_mastery_points       8
# dtype: int64

# %%
#
